# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import os
import pickle

from python_speech_features import mel2hz, hz2mel

plt.rc('font', family='Times New Roman')

# %matplotlib inline

# %%
data_dir = '/home/yangwenhao/local/project/SpeakerVerification-pytorch'

# %%
female_fratio = np.load(data_dir+'/Data/fratio/vox1/klsp/dev_female/fratio_20000.npy')
male_fratio = np.load(data_dir+'/Data/fratio/vox1/klsp/dev_male/fratio_20000.npy')
# cnc_fratio = np.load(data_dir+'/Data/fratio/cnceleb/klsp/dev/fratio_20000.npy')

plt.figure(figsize=(12, 4))

x = np.arange(161) * 8000 / (161 - 1)
# x = hz2mel(x)
plt.title('Fratio for female and male in VoxCeleb1', fontsize=18)
plt.plot(x, female_fratio, linewidth=2, marker='.')
plt.plot(x, male_fratio, linewidth=2, marker='x')

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

plt.legend(["female", "male"], fontsize=16)

# %%
female_fratio = np.load(data_dir+'/Data/fratio/vox1/klsp/dev_female/fratio_20000.npy')
male_fratio = np.load(data_dir+'/Data/fratio/vox1/klsp/dev_male/fratio_20000.npy')
# cnc_fratio = np.load(data_dir+'/Data/fratio/cnceleb/klsp/dev/fratio_20000.npy')

plt.figure(figsize=(12, 4))

x = np.arange(161) * 8000 / (161 - 1)
# x = hz2mel(x)
plt.title('Fratio for female and male in VoxCeleb1', fontsize=18)
plt.plot(x, male_fratio/female_fratio, linewidth=2, marker='.')
# plt.plot(x, 1/male_fratio, linewidth=2, marker='x')

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

plt.legend(["female", "male"], fontsize=16)

# %%
plt.figure(figsize=(16, 6))

cnc_fratio = np.load(data_dir+'/Data/fratio/cnceleb/klsp/dev/fratio_20000.npy')
vo1_fratio = np.load(data_dir+'/Data/fratio/vox1/klsp/dev/fratio_10000.npy')


x = np.arange(161) * 8000 / (161 - 1)
# x = hz2mel(x)

plt.plot(x, cnc_fratio, linewidth=2, marker='.')
plt.plot(x, vo1_fratio, linewidth=2, marker='.')

# plt.plot(x, 1/male_fratio, linewidth=2, marker='x')

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid()

plt.legend(["cnceleb", "voxceleb1"], fontsize=16)
