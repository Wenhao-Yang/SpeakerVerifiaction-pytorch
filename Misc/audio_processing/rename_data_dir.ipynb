# %%
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf
from tqdm import tqdm
import os

# %%
data_dir = '/home/yangwenhao/project/lstm_speaker_verification'

# %% [markdown]
# ### Rename wav.scp path

# %%
all_sid = set([])
with open(data_dir + '/data/vox2/dev/spk2utt', 'r') as f:
    for l in f.readlines():
        all_sid.add(l.split()[0])
        
with open(data_dir + '/data/vox2/dev/spk2gender_all', 'r') as f, \
     open(data_dir + '/data/vox2/dev/spk2gender', 'w') as f1:
    for l in f.readlines():
        sid, g = l.split()
        if sid in all_sid:
            f1.write(sid + ' ' + g + '\n')

# %%
subset_name = 'all_radsnr05' #'radio/test_chn2_dist3' #'all_wb_radsnr2' #test_radio_chn2 test_radchn2_dist1 test_radsnr5
wavstr = '/aac/'
new_wavstr = '/aac_nb_randsnr05/' #'/wav_radio_chn2/' #'/wav_wb_randsnr2/' #'/wav_radchn2_dist1/' wav_nb_randsnr5
resets = [['radio/dev_radsnr05', '/aac_nb_randsnr05/']]


# resets = [['radio/dev_radsnr1', '/wav_nb_radsnr1/']]
# wavstr = '/wav/'

for subset_name,new_wavstr in resets:
    uid2path = []

    wav_scp = data_dir + '/data/vox2/%s/wav.scp'%(subset_name)

    with open(wav_scp, 'r') as f:
        for l in f.readlines():
            uid, upath = l.split()
            upath = upath.replace(wavstr, new_wavstr)
            uid2path.append(' '.join([uid, upath]))

    print(uid2path[0])

    with open(wav_scp, 'w') as f:
        for l in uid2path:
            f.write(l + '\n')
# Out:
# id00012-21Uxsk56VDQ-00001-radsnr05 /home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id00012/21Uxsk56VDQ/00001.wav

# %% [markdown]
# ### utt2dur valid

# %%
utt2dur_d = {}
with open(data_dir + '/data/vox2/dev/utt2dur', 'r') as f:
# with open(data_dir + '/data/vox1/klfb/dev_fb40/utt2dur', 'r') as f:
    for l in f.readlines():
        uid, dur = l.split()
        utt2dur_d[uid] = float(dur)

# %%
subset_name = 'radio/dev_radsnr05'
wav_scp = data_dir + '/data/vox2/%s/wav.scp'%(subset_name)

# subset_name = 'radio/dev_radsnr1'
# wav_scp = data_dir + '/data/vox1/%s/wav.scp'%(subset_name)

with open(wav_scp, 'r') as f:
    for l in tqdm(f.readlines()):
        uid, upath = l.split()
        original_uid = '-'.join(uid.split('-')[:-1])
        
        if os.path.exists(upath):
            wav, sr = sf.read(upath)
            if np.abs(len(wav)/sr - utt2dur_d[original_uid])>4:
                print(uid, upath)
# Out:
#  94%|█████████▍| 1028438/1092009 [33:09<01:34, 671.05it/s]
# id08704-ysOE7E4PrEk-00479-radsnr05 /home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08704/ysOE7E4PrEk/00479.wav
# id08704-ysOE7E4PrEk-00485-radsnr05 /home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08704/ysOE7E4PrEk/00485.wav
# id08704-ysOE7E4PrEk-00487-radsnr05 /home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08704/ysOE7E4PrEk/00487.wav
# id08705-4fpMW5neR2k-00012-radsnr05 /home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/4fpMW5neR2k/00012.wav
# id08705-4fpMW5neR2k-00013-radsnr05 /home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/4fpMW5neR2k/00013.wav
# id08705-50rey47PJr8-00029-radsnr05 /home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/50rey47PJr8/00029.wav
# id08705-50rey47PJr8-00031-radsnr05 /home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/50rey47PJr8/00031.wav
# id08705-5GRjAGUa-5o-00033-radsnr05 /home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/5GRjAGUa-5o/00033.wav
# id08705-5GRjAGUa-5o-00035-radsnr05 /home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/5GRjAGUa-5o/00035.wav
# id08705-A5mdQ43dycE-00039-radsnr05 /home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/A5mdQ43dycE/00039.wav
# id08705-A5mdQ43dycE-00045-radsnr05 /home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/A5mdQ43dycE/00045.wav
# id08705-A5mdQ43dycE-00046-radsnr05 /home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/A5mdQ43dycE/00046.wav
# 100%|██████████| 1092009/1092009 [34:35<00:00, 526.11it/s]

# %%
miss_wav = ['/home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08704/ysOE7E4PrEk/00479.wav', '/home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08704/ysOE7E4PrEk/00485.wav', '/home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08704/ysOE7E4PrEk/00487.wav', '/home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/4fpMW5neR2k/00012.wav', '/home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/4fpMW5neR2k/00013.wav', '/home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/50rey47PJr8/00029.wav', '/home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/50rey47PJr8/00031.wav', '/home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/5GRjAGUa-5o/00033.wav', '/home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/5GRjAGUa-5o/00035.wav', '/home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/A5mdQ43dycE/00039.wav', '/home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/A5mdQ43dycE/00045.wav', '/home/yangwenhao/dataset/voxceleb2/dev/aac_nb_randsnr05/id08705/A5mdQ43dycE/00046.wav'
]

for w in miss_wav:
    os.remove(w)

# %%
subset_name = 'all_radsnr05' #'radio/test_chn2_dist3' #'all_wb_radsnr2' #test_radio_chn2 test_radchn2_dist1 test_radsnr5
wavstr = '/aac/'
new_wavstr = '/aac_nb_randsnr05/' #'/wav_radio_chn2/' #'/wav_wb_randsnr2/' #'/wav_radchn2_dist1/' wav_nb_randsnr5
resets = ['radio/dev_radsnr05']


# resets = [['radio/dev_radsnr1', '/wav_nb_radsnr1/']]
# wavstr = '/wav/'

for subset_name in resets:
    uid2path = []

    wav_scp = data_dir + '/data/vox2/%s/wav.scp'%(subset_name)

    with open(wav_scp, 'r') as f1, \
        open(data_dir + '/data/vox2/%s/utt2dur'%(subset_name), 'w') as f2:
        for l in tqdm(f1.readlines()):
            uid, upath = l.split()
            wav, sr = sf.read(upath)
            dur = len(wav) / sr
            
            f2.write(uid + ' {:.4f}'.format(dur) + '\n')
# Out:
# 100%|██████████| 1092009/1092009 [33:52<00:00, 537.33it/s]

# %% [markdown]
# ### Rename tirals uid siffix

# %%
# 
# for s in ['easy', 'hard', 'female', 'male']:
s = 'original'#'radsnr5'
trials_f = '/home/yangwenhao/project/lstm_speaker_verification/data/vox1/test/trials' #_%s'%(s)
suffix = '-radsnr5' #'-rd2dist1' #-radchn2
# test_resets = [['radio/test_chn4', '-radchn4'],
#               ['radio/test_chn5', '-radchn5'],
#               ['radio/test_chn6', '-radchn5']]

# test_resets = [['radio/test_chn22', '-radchn22'],
#               ['radio/test_chn1', '-radchn1'],]

# test_resets = [['radio/test_chna', '-radchna'],
#               ['radio/test_chn0', '-radchn0'],]
test_resets = [['radio/test_wb_chn2', '-radwbchn2'],
              ['radio/test_wb_chn4', '-radwbchn4'],]

for subset_name, suffix in test_resets:
    trials = []
    trials_f = '/home/yangwenhao/project/lstm_speaker_verification/data/vox1/test/trials' #_%s'%(s)

    with open(trials_f, 'r') as f:
        for l in f.readlines():
            a, b, c = l.split()

            trials.append(' '.join([a + suffix, b + suffix, c]))

    trials_name = 'trials_{}'.format(s)
    trials_f = '/home/yangwenhao/project/lstm_speaker_verification/data/vox1/%s/%s'%(subset_name, trials_name)
    with open(trials_f, 'w') as f:
        for l in trials:
            f.write(l + '\n')

# %% [markdown]
# ### utt2dur

# %%
# subset_name = 'dev_16'
subset_names = ['dev', 'dev_64', 'dev_32', 'dev_16']
for s in subset_names:
    utt2dur_f = data_dir + '/data/vox2/%s/utt2dur'%(s)
    total_dur = 0
    with open(utt2dur_f, 'r') as f:
        for l in f.readlines():
            uid, dur = l.split()
            total_dur += float(dur)
    print(s)
    print('Seconds: {:.2f}'.format(total_dur))
    print('Minutes: {:.2f}'.format(total_dur / 60 ))
    print('Hours:   {:.2f}'.format(total_dur / 60 / 60))
    
# dev
# Seconds: 8496542.85
# Minutes: 141609.05
# Hours:   2360.15
# dev_64
# Seconds: 3726305.15
# Minutes: 62105.09
# Hours:   1035.08
# dev_32
# Seconds: 1493623.81
# Minutes: 24893.73
# Hours:   414.90
# dev_16
# Seconds: 747998.53
# Minutes: 12466.64
# Hours:   207.78
# dev_16_snr05
# Seconds: 747447.08
# Minutes: 12457.45
# Hours:   207.62
# Out:
# dev
# Seconds: 8496542.85
# Minutes: 141609.05
# Hours:   2360.15
# dev_64
# Seconds: 3726305.15
# Minutes: 62105.09
# Hours:   1035.08
# dev_32
# Seconds: 1493623.81
# Minutes: 24893.73
# Hours:   414.90
# dev_16
# Seconds: 747998.53
# Minutes: 12466.64
# Hours:   207.78

# %%
wav_f = data_dir + '/data/vox2/radio/dev_16_radsnr05/wav.scp'
utt2dur_f = data_dir + '/data/vox2/radio/dev_16_radsnr05/utt2dur.new'

total_dur = 0
with open(wav_f, 'r') as f, \
    open(utt2dur_f, 'w') as f2:
    for l in tqdm(f.readlines(), ncols=50):
        uid, upath = l.split()
        wav, sr = sf.read(upath)
        dur = len(wav)/sr
        
        f2.write(uid + ' ' + '{:.2f}\n'.format(dur))
        
        total_dur += dur

print('Seconds: {:.2f}'.format(total_dur))
print('Minutes: {:.2f}'.format(total_dur / 60 ))
print('Hours:   {:.2f}'.format(total_dur / 60 / 60))
# Out:
# 100%|█████| 95904/95904 [00:47<00:00, 2004.92it/s]
# Seconds: 747447.08
# Minutes: 12457.45
# Hours:   207.62

# %%
207.62 + 1035.08
# Out:
# 1242.6999999999998

# %%
5994*32
# Out:
# 191808

# %%
# wav_f = data_dir + '/data/vox2/dev/wav.scp'
utt2dur_f = data_dir + '/data/vox2/dev/utt2dur'

total_dur = 0
with open(utt2dur_f, 'r') as f2:
    for l in tqdm(f2.readlines(), ncols=50):
        uid, dur = l.split()
        dur = float(dur)
                
        total_dur += dur

print('Seconds: {:.2f}'.format(total_dur))
print('Minutes: {:.2f}'.format(total_dur / 60 ))
print('Hours:   {:.2f}'.format(total_dur / 60 / 60))
# Out:
# 100%|█| 1092009/1092009 [00:00<00:00, 1421410.80it
# Seconds: 8496542.85
# Minutes: 141609.05
# Hours:   2360.15

# %% [markdown]
# ### VoxSRV 2020 2021

# %%
save_path = '/home/yangwenhao/project/lstm_speaker_verification/data/voxsrc'

# %%
os.path.basename('/work/2023/yangwenhao/dataset/voxsrc2020.trials')
# Out:
# 'voxsrc2020.trials'

# %%
trials_f = ['/work/2023/yangwenhao/dataset/voxsrc2020.trials',
           '/work/2023/yangwenhao/dataset/voxsrc2021.trials',
           '/work/2023/yangwenhao/dataset/voxsrc2022.trials']

# %%
for t in trials_f:
    with open(t, 'r') as f, \
         open(os.path.join(save_path, os.path.basename(t)), 'w') as fw:
        for l in f.readlines():
            target, uida, uidb = l.split()
            uida = '-'.join(uida.split('/')[-3:])[:-4]
            uidb = '-'.join(uidb.split('/')[-3:])[:-4]
            if target == '1':
                target = 'target'
            elif target == '0':
                target = 'nontarget'
            fw.write(uida + ' ' + uidb + ' ' + target + '\n')

# %%
trials_uids = {}
for t in trials_f:
    uids = set([])
    with open(t, 'r') as f:
        for l in f.readlines():
            target, uida, uidb = l.split()
            # print(type(target), target == '1')
            # break
            uida = '-'.join(uida.split('/')[-3:])[:-4]
            uidb = '-'.join(uidb.split('/')[-3:])[:-4]
            uids.add(uida)
            uids.add(uidb)
    trials_uids[t] = uids

# %%
for t in trials_uids:
    print(len(trials_uids[t]))
# Out:
# 140185
# 64711
# 110366

# %%
vox1_uids = set([])
with open('/home/yangwenhao/project/lstm_speaker_verification/data/vox1/all/wav.scp',
          'r') as f:
    for l in f.readlines():
        uid = l.split()[0]
        vox1_uids.add(uid)

# %%
print(len(vox1_uids))
# Out:
# 153516

# %%
miss_uids = {}
for t in trials_uids:
    miss_uids[t] = []
    for uid in trials_uids[t]:
        if uid not in vox1_uids:
            miss_uids[t].append(uid)

# %%
for t in trials_uids:
    print(t, len(miss_uids[t]))
# Out:
# /work/2023/yangwenhao/dataset/voxsrc2020.trials 2076
# /work/2023/yangwenhao/dataset/voxsrc2021.trials 0
# /work/2023/yangwenhao/dataset/voxsrc2022.trials 6683

# %%
miss_uids['/work/2023/yangwenhao/dataset/voxsrc2022.trials']
# Out:
# ['VoxSRC2022_dev-dev_02191',
#  'VoxSRC2022_dev-dev_06364',
#  'VoxSRC2022_dev-dev_00761',
#  'VoxSRC2022_dev-dev_04835',
#  'VoxSRC2022_dev-dev_03560',
#  'VoxSRC2022_dev-dev_01951',
#  'VoxSRC2022_dev-dev_03369',
#  'VoxSRC2022_dev-dev_01864',
#  'VoxSRC2022_dev-dev_05026',
#  'VoxSRC2022_dev-dev_06309',
#  'VoxSRC2022_dev-dev_05293',
#  'VoxSRC2022_dev-dev_06654',
#  'VoxSRC2022_dev-dev_05822',
#  'VoxSRC2022_dev-dev_05391',
#  'VoxSRC2022_dev-dev_00747',
#  'VoxSRC2022_dev-dev_01622',
#  'VoxSRC2022_dev-dev_04830',
#  'VoxSRC2022_dev-dev_01261',
#  'VoxSRC2022_dev-dev_03416',
#  'VoxSRC2022_dev-dev_06522',
#  'VoxSRC2022_dev-dev_01019',
#  'VoxSRC2022_dev-dev_04384',
#  'VoxSRC2022_dev-dev_03215',
#  'VoxSRC2022_dev-dev_05403',
#  'VoxSRC2022_dev-dev_05101',
#  'VoxSRC2022_dev-dev_01585',
#  'VoxSRC2022_dev-dev_03433',
#  'VoxSRC2022_dev-dev_04792',
#  'VoxSRC2022_dev-dev_02845',
#  'VoxSRC2022_dev-dev_02197',
#  'VoxSRC2022_dev-dev_05415',
#  'VoxSRC2022_dev-dev_06400',
#  'VoxSRC2022_dev-dev_05667',
#  'VoxSRC2022_dev-dev_04637',
#  'VoxSRC2022_dev-dev_05371',
#  'VoxSRC2022_dev-dev_03161',
#  'VoxSRC2022_dev-dev_00249',
#  'VoxSRC2022_dev-dev_04417',
#  'VoxSRC2022_dev-dev_00853',
#  'VoxSRC2022_dev-dev_01407',
#  'VoxSRC2022_dev-dev_01226',
#  'VoxSRC2022_dev-dev_02204',
#  'VoxSRC2022_dev-dev_02381',
#  'VoxSRC2022_dev-dev_02677',
#  'VoxSRC2022_dev-dev_01981',
#  'VoxSRC2022_dev-dev_05408',
#  'VoxSRC2022_dev-dev_04689',
#  'VoxSRC2022_dev-dev_02065',
#  'VoxSRC2022_dev-dev_06432',
#  'VoxSRC2022_dev-dev_01179',
#  'VoxSRC2022_dev-dev_04881',
#  'VoxSRC2022_dev-dev_03557',
#  'VoxSRC2022_dev-dev_04142',
#  'VoxSRC2022_dev-dev_03816',
#  'VoxSRC2022_dev-dev_01054',
#  'VoxSRC2022_dev-dev_01394',
#  'VoxSRC2022_dev-dev_00033',
#  'VoxSRC2022_dev-dev_04952',
#  'VoxSRC2022_dev-dev_01971',
#  'VoxSRC2022_dev-dev_05915',
#  'VoxSRC2022_dev-dev_02524',
#  'VoxSRC2022_dev-dev_02662',
#  'VoxSRC2022_dev-dev_02059',
#  'VoxSRC2022_dev-dev_01535',
#  'VoxSRC2022_dev-dev_06388',
#  'VoxSRC2022_dev-dev_02960',
#  'VoxSRC2022_dev-dev_04833',
#  'VoxSRC2022_dev-dev_04642',
#  'VoxSRC2022_dev-dev_01876',
#  'VoxSRC2022_dev-dev_05948',
#  'VoxSRC2022_dev-dev_02130',
#  'VoxSRC2022_dev-dev_02361',
#  'VoxSRC2022_dev-dev_01061',
#  'VoxSRC2022_dev-dev_03365',
#  'VoxSRC2022_dev-dev_01655',
#  'VoxSRC2022_dev-dev_02772',
#  'VoxSRC2022_dev-dev_06015',
#  'VoxSRC2022_dev-dev_02110',
#  'VoxSRC2022_dev-dev_01696',
#  'VoxSRC2022_dev-dev_02778',
#  'VoxSRC2022_dev-dev_03954',
#  'VoxSRC2022_dev-dev_02773',
#  'VoxSRC2022_dev-dev_03591',
#  'VoxSRC2022_dev-dev_05088',
#  'VoxSRC2022_dev-dev_01921',
#  'VoxSRC2022_dev-dev_05288',
#  'VoxSRC2022_dev-dev_01291',
#  'VoxSRC2022_dev-dev_02298',
#  'VoxSRC2022_dev-dev_00687',
#  'VoxSRC2022_dev-dev_02887',
#  'VoxSRC2022_dev-dev_01433',
#  'VoxSRC2022_dev-dev_05267',
#  'VoxSRC2022_dev-dev_03975',
#  'VoxSRC2022_dev-dev_02388',
#  'VoxSRC2022_dev-dev_02102',
#  'VoxSRC2022_dev-dev_01450',
#  'VoxSRC2022_dev-dev_00542',
#  'VoxSRC2022_dev-dev_05537',
#  'VoxSRC2022_dev-dev_05857',
#  'VoxSRC2022_dev-dev_03812',
#  'VoxSRC2022_dev-dev_04684',
#  'VoxSRC2022_dev-dev_01108',
#  'VoxSRC2022_dev-dev_01736',
#  'VoxSRC2022_dev-dev_01146',
#  'VoxSRC2022_dev-dev_04551',
#  'VoxSRC2022_dev-dev_03206',
#  'VoxSRC2022_dev-dev_00438',
#  'VoxSRC2022_dev-dev_01139',
#  'VoxSRC2022_dev-dev_03541',
#  'VoxSRC2022_dev-dev_06136',
#  'VoxSRC2022_dev-dev_01208',
#  'VoxSRC2022_dev-dev_03202',
#  'VoxSRC2022_dev-dev_01761',
#  'VoxSRC2022_dev-dev_00182',
#  'VoxSRC2022_dev-dev_04139',
#  'VoxSRC2022_dev-dev_04132',
#  'VoxSRC2022_dev-dev_01034',
#  'VoxSRC2022_dev-dev_04105',
#  'VoxSRC2022_dev-dev_05244',
#  'VoxSRC2022_dev-dev_02979',
#  'VoxSRC2022_dev-dev_05965',
#  'VoxSRC2022_dev-dev_00618',
#  'VoxSRC2022_dev-dev_00968',
#  'VoxSRC2022_dev-dev_04310',
#  'VoxSRC2022_dev-dev_03183',
#  'VoxSRC2022_dev-dev_05192',
#  'VoxSRC2022_dev-dev_03742',
#  'VoxSRC2022_dev-dev_00553',
#  'VoxSRC2022_dev-dev_05113',
#  'VoxSRC2022_dev-dev_01091',
#  'VoxSRC2022_dev-dev_03790',
#  'VoxSRC2022_dev-dev_05740',
#  'VoxSRC2022_dev-dev_03170',
#  'VoxSRC2022_dev-dev_04826',
#  'VoxSRC2022_dev-dev_03050',
#  'VoxSRC2022_dev-dev_03768',
#  'VoxSRC2022_dev-dev_05730',
#  'VoxSRC2022_dev-dev_00894',
#  'VoxSRC2022_dev-dev_03220',
#  'VoxSRC2022_dev-dev_05988',
#  'VoxSRC2022_dev-dev_02686',
#  'VoxSRC2022_dev-dev_04315',
#  'VoxSRC2022_dev-dev_06340',
#  'VoxSRC2022_dev-dev_03072',
#  'VoxSRC2022_dev-dev_00867',
#  'VoxSRC2022_dev-dev_06581',
#  'VoxSRC2022_dev-dev_04013',
#  'VoxSRC2022_dev-dev_03505',
#  'VoxSRC2022_dev-dev_05990',
#  'VoxSRC2022_dev-dev_02409',
#  'VoxSRC2022_dev-dev_03419',
#  'VoxSRC2022_dev-dev_05194',
#  'VoxSRC2022_dev-dev_04201',
#  'VoxSRC2022_dev-dev_00473',
#  'VoxSRC2022_dev-dev_02769',
#  'VoxSRC2022_dev-dev_01561',
#  'VoxSRC2022_dev-dev_05889',
#  'VoxSRC2022_dev-dev_02881',
#  'VoxSRC2022_dev-dev_01438',
#  'VoxSRC2022_dev-dev_00812',
#  'VoxSRC2022_dev-dev_03044',
#  'VoxSRC2022_dev-dev_04040',
#  'VoxSRC2022_dev-dev_00802',
#  'VoxSRC2022_dev-dev_03698',
#  'VoxSRC2022_dev-dev_01231',
#  'VoxSRC2022_dev-dev_00090',
#  'VoxSRC2022_dev-dev_04430',
#  'VoxSRC2022_dev-dev_05961',
#  'VoxSRC2022_dev-dev_02416',
#  'VoxSRC2022_dev-dev_00837',
#  'VoxSRC2022_dev-dev_05975',
#  'VoxSRC2022_dev-dev_01325',
#  'VoxSRC2022_dev-dev_02209',
#  'VoxSRC2022_dev-dev_01780',
#  'VoxSRC2022_dev-dev_02163',
#  'VoxSRC2022_dev-dev_06389',
#  'VoxSRC2022_dev-dev_04784',
#  'VoxSRC2022_dev-dev_06604',
#  'VoxSRC2022_dev-dev_02014',
#  'VoxSRC2022_dev-dev_04592',
#  'VoxSRC2022_dev-dev_05156',
#  'VoxSRC2022_dev-dev_04673',
#  'VoxSRC2022_dev-dev_05295',
#  'VoxSRC2022_dev-dev_05938',
#  'VoxSRC2022_dev-dev_03256',
#  'VoxSRC2022_dev-dev_05561',
#  'VoxSRC2022_dev-dev_03404',
#  'VoxSRC2022_dev-dev_00871',
#  'VoxSRC2022_dev-dev_00948',
#  'VoxSRC2022_dev-dev_02582',
#  'VoxSRC2022_dev-dev_01401',
#  'VoxSRC2022_dev-dev_01046',
#  'VoxSRC2022_dev-dev_02706',
#  'VoxSRC2022_dev-dev_00823',
#  'VoxSRC2022_dev-dev_06385',
#  'VoxSRC2022_dev-dev_04360',
#  'VoxSRC2022_dev-dev_00709',
#  'VoxSRC2022_dev-dev_01086',
#  'VoxSRC2022_dev-dev_01664',
#  'VoxSRC2022_dev-dev_02038',
#  'VoxSRC2022_dev-dev_05210',
#  'VoxSRC2022_dev-dev_03915',
#  'VoxSRC2022_dev-dev_02341',
#  'VoxSRC2022_dev-dev_05419',
#  'VoxSRC2022_dev-dev_05892',
#  'VoxSRC2022_dev-dev_00525',
#  'VoxSRC2022_dev-dev_05420',
#  'VoxSRC2022_dev-dev_04398',
#  'VoxSRC2022_dev-dev_00053',
#  'VoxSRC2022_dev-dev_02147',
#  'VoxSRC2022_dev-dev_06352',
#  'VoxSRC2022_dev-dev_02273',
#  'VoxSRC2022_dev-dev_05721',
#  'VoxSRC2022_dev-dev_04411',
#  'VoxSRC2022_dev-dev_00897',
#  'VoxSRC2022_dev-dev_02104',
#  'VoxSRC2022_dev-dev_04185',
#  'VoxSRC2022_dev-dev_03960',
#  'VoxSRC2022_dev-dev_05474',
#  'VoxSRC2022_dev-dev_05936',
#  'VoxSRC2022_dev-dev_00356',
#  'VoxSRC2022_dev-dev_04574',
#  'VoxSRC2022_dev-dev_04801',
#  'VoxSRC2022_dev-dev_01690',
#  'VoxSRC2022_dev-dev_03876',
#  'VoxSRC2022_dev-dev_00299',
#  'VoxSRC2022_dev-dev_06114',
#  'VoxSRC2022_dev-dev_04889',
#  'VoxSRC2022_dev-dev_01912',
#  'VoxSRC2022_dev-dev_06431',
#  'VoxSRC2022_dev-dev_04102',
#  'VoxSRC2022_dev-dev_05380',
#  'VoxSRC2022_dev-dev_04878',
#  'VoxSRC2022_dev-dev_05480',
#  'VoxSRC2022_dev-dev_04475',
#  'VoxSRC2022_dev-dev_04075',
#  'VoxSRC2022_dev-dev_00258',
#  'VoxSRC2022_dev-dev_03255',
#  'VoxSRC2022_dev-dev_00626',
#  'VoxSRC2022_dev-dev_03322',
#  'VoxSRC2022_dev-dev_00765',
#  'VoxSRC2022_dev-dev_00543',
#  'VoxSRC2022_dev-dev_02269',
#  'VoxSRC2022_dev-dev_01413',
#  'VoxSRC2022_dev-dev_00956',
#  'VoxSRC2022_dev-dev_01510',
#  'VoxSRC2022_dev-dev_04977',
#  'VoxSRC2022_dev-dev_05446',
#  'VoxSRC2022_dev-dev_06351',
#  'VoxSRC2022_dev-dev_05204',
#  'VoxSRC2022_dev-dev_02672',
#  'VoxSRC2022_dev-dev_04641',
#  'VoxSRC2022_dev-dev_01806',
#  'VoxSRC2022_dev-dev_04089',
#  'VoxSRC2022_dev-dev_00819',
#  'VoxSRC2022_dev-dev_04182',
#  'VoxSRC2022_dev-dev_00239',
#  'VoxSRC2022_dev-dev_03121',
#  'VoxSRC2022_dev-dev_00503',
#  'VoxSRC2022_dev-dev_00061',
#  'VoxSRC2022_dev-dev_04964',
#  'VoxSRC2022_dev-dev_02321',
#  'VoxSRC2022_dev-dev_02202',
#  'VoxSRC2022_dev-dev_06625',
#  'VoxSRC2022_dev-dev_01948',
#  'VoxSRC2022_dev-dev_06141',
#  'VoxSRC2022_dev-dev_02326',
#  'VoxSRC2022_dev-dev_04639',
#  'VoxSRC2022_dev-dev_04472',
#  'VoxSRC2022_dev-dev_04922',
#  'VoxSRC2022_dev-dev_01157',
#  'VoxSRC2022_dev-dev_06321',
#  'VoxSRC2022_dev-dev_00409',
#  'VoxSRC2022_dev-dev_02860',
#  'VoxSRC2022_dev-dev_02584',
#  'VoxSRC2022_dev-dev_02915',
#  'VoxSRC2022_dev-dev_00035',
#  'VoxSRC2022_dev-dev_05843',
#  'VoxSRC2022_dev-dev_01994',
#  'VoxSRC2022_dev-dev_03850',
#  'VoxSRC2022_dev-dev_04248',
#  'VoxSRC2022_dev-dev_06546',
#  'VoxSRC2022_dev-dev_04138',
#  'VoxSRC2022_dev-dev_02711',
#  'VoxSRC2022_dev-dev_02924',
#  'VoxSRC2022_dev-dev_01314',
#  'VoxSRC2022_dev-dev_02590',
#  'VoxSRC2022_dev-dev_02890',
#  'VoxSRC2022_dev-dev_02189',
#  'VoxSRC2022_dev-dev_01292',
#  'VoxSRC2022_dev-dev_02739',
#  'VoxSRC2022_dev-dev_04069',
#  'VoxSRC2022_dev-dev_02664',
#  'VoxSRC2022_dev-dev_00972',
#  'VoxSRC2022_dev-dev_04072',
#  'VoxSRC2022_dev-dev_06507',
#  'VoxSRC2022_dev-dev_04971',
#  'VoxSRC2022_dev-dev_06324',
#  'VoxSRC2022_dev-dev_01682',
#  'VoxSRC2022_dev-dev_05039',
#  'VoxSRC2022_dev-dev_04060',
#  'VoxSRC2022_dev-dev_02892',
#  'VoxSRC2022_dev-dev_04743',
#  'VoxSRC2022_dev-dev_03033',
#  'VoxSRC2022_dev-dev_00952',
#  'VoxSRC2022_dev-dev_00763',
#  'VoxSRC2022_dev-dev_02735',
#  'VoxSRC2022_dev-dev_06428',
#  'VoxSRC2022_dev-dev_06453',
#  'VoxSRC2022_dev-dev_04312',
#  'VoxSRC2022_dev-dev_06337',
#  'VoxSRC2022_dev-dev_04080',
#  'VoxSRC2022_dev-dev_06069',
#  'VoxSRC2022_dev-dev_06128',
#  'VoxSRC2022_dev-dev_00820',
#  'VoxSRC2022_dev-dev_04666',
#  'VoxSRC2022_dev-dev_00221',
#  'VoxSRC2022_dev-dev_05547',
#  'VoxSRC2022_dev-dev_01809',
#  'VoxSRC2022_dev-dev_05525',
#  'VoxSRC2022_dev-dev_06571',
#  'VoxSRC2022_dev-dev_03081',
#  'VoxSRC2022_dev-dev_03207',
#  'VoxSRC2022_dev-dev_03885',
#  'VoxSRC2022_dev-dev_01825',
#  'VoxSRC2022_dev-dev_01758',
#  'VoxSRC2022_dev-dev_02349',
#  'VoxSRC2022_dev-dev_00923',
#  'VoxSRC2022_dev-dev_00536',
#  'VoxSRC2022_dev-dev_01620',
#  'VoxSRC2022_dev-dev_05390',
#  'VoxSRC2022_dev-dev_04097',
#  'VoxSRC2022_dev-dev_01463',
#  'VoxSRC2022_dev-dev_01814',
#  'VoxSRC2022_dev-dev_04585',
#  'VoxSRC2022_dev-dev_01979',
#  'VoxSRC2022_dev-dev_04630',
#  'VoxSRC2022_dev-dev_05720',
#  'VoxSRC2022_dev-dev_03699',
#  'VoxSRC2022_dev-dev_03953',
#  'VoxSRC2022_dev-dev_01191',
#  'VoxSRC2022_dev-dev_01583',
#  'VoxSRC2022_dev-dev_06173',
#  'VoxSRC2022_dev-dev_02327',
#  'VoxSRC2022_dev-dev_01283',
#  'VoxSRC2022_dev-dev_03264',
#  'VoxSRC2022_dev-dev_03179',
#  'VoxSRC2022_dev-dev_05991',
#  'VoxSRC2022_dev-dev_00565',
#  'VoxSRC2022_dev-dev_00918',
#  'VoxSRC2022_dev-dev_02112',
#  'VoxSRC2022_dev-dev_04691',
#  'VoxSRC2022_dev-dev_02699',
#  'VoxSRC2022_dev-dev_03357',
#  'VoxSRC2022_dev-dev_00530',
#  'VoxSRC2022_dev-dev_00331',
#  'VoxSRC2022_dev-dev_02929',
#  'VoxSRC2022_dev-dev_03474',
#  'VoxSRC2022_dev-dev_04773',
#  'VoxSRC2022_dev-dev_06436',
#  'VoxSRC2022_dev-dev_04179',
#  'VoxSRC2022_dev-dev_05405',
#  'VoxSRC2022_dev-dev_02429',
#  'VoxSRC2022_dev-dev_02180',
#  'VoxSRC2022_dev-dev_03450',
#  'VoxSRC2022_dev-dev_05954',
#  'VoxSRC2022_dev-dev_02445',
#  'VoxSRC2022_dev-dev_02566',
#  'VoxSRC2022_dev-dev_06341',
#  'VoxSRC2022_dev-dev_00162',
#  'VoxSRC2022_dev-dev_06651',
#  'VoxSRC2022_dev-dev_01087',
#  'VoxSRC2022_dev-dev_00472',
#  'VoxSRC2022_dev-dev_04505',
#  'VoxSRC2022_dev-dev_06032',
#  'VoxSRC2022_dev-dev_03985',
#  'VoxSRC2022_dev-dev_03677',
#  'VoxSRC2022_dev-dev_05130',
#  'VoxSRC2022_dev-dev_00591',
#  'VoxSRC2022_dev-dev_01529',
#  'VoxSRC2022_dev-dev_00590',
#  'VoxSRC2022_dev-dev_01569',
#  'VoxSRC2022_dev-dev_01203',
#  'VoxSRC2022_dev-dev_02426',
#  'VoxSRC2022_dev-dev_00768',
#  'VoxSRC2022_dev-dev_01454',
#  'VoxSRC2022_dev-dev_05847',
#  'VoxSRC2022_dev-dev_01954',
#  'VoxSRC2022_dev-dev_06241',
#  'VoxSRC2022_dev-dev_02358',
#  'VoxSRC2022_dev-dev_04420',
#  'VoxSRC2022_dev-dev_06359',
#  'VoxSRC2022_dev-dev_01326',
#  'VoxSRC2022_dev-dev_02511',
#  'VoxSRC2022_dev-dev_02927',
#  'VoxSRC2022_dev-dev_05841',
#  'VoxSRC2022_dev-dev_04415',
#  'VoxSRC2022_dev-dev_03002',
#  'VoxSRC2022_dev-dev_04553',
#  'VoxSRC2022_dev-dev_04779',
#  'VoxSRC2022_dev-dev_00805',
#  'VoxSRC2022_dev-dev_00569',
#  'VoxSRC2022_dev-dev_06314',
#  'VoxSRC2022_dev-dev_01250',
#  'VoxSRC2022_dev-dev_04644',
#  'VoxSRC2022_dev-dev_05980',
#  'VoxSRC2022_dev-dev_05950',
#  'VoxSRC2022_dev-dev_02698',
#  'VoxSRC2022_dev-dev_05597',
#  'VoxSRC2022_dev-dev_01323',
#  'VoxSRC2022_dev-dev_01803',
#  'VoxSRC2022_dev-dev_03744',
#  'VoxSRC2022_dev-dev_02031',
#  'VoxSRC2022_dev-dev_01774',
#  'VoxSRC2022_dev-dev_00598',
#  'VoxSRC2022_dev-dev_04208',
#  'VoxSRC2022_dev-dev_01466',
#  'VoxSRC2022_dev-dev_02678',
#  'VoxSRC2022_dev-dev_01375',
#  'VoxSRC2022_dev-dev_02245',
#  'VoxSRC2022_dev-dev_05734',
#  'VoxSRC2022_dev-dev_05046',
#  'VoxSRC2022_dev-dev_01811',
#  'VoxSRC2022_dev-dev_05658',
#  'VoxSRC2022_dev-dev_05838',
#  'VoxSRC2022_dev-dev_00222',
#  'VoxSRC2022_dev-dev_00938',
#  'VoxSRC2022_dev-dev_04863',
#  'VoxSRC2022_dev-dev_03148',
#  'VoxSRC2022_dev-dev_05340',
#  'VoxSRC2022_dev-dev_05006',
#  'VoxSRC2022_dev-dev_06198',
#  'VoxSRC2022_dev-dev_04410',
#  'VoxSRC2022_dev-dev_05175',
#  'VoxSRC2022_dev-dev_01072',
#  'VoxSRC2022_dev-dev_02879',
#  'VoxSRC2022_dev-dev_04572',
#  'VoxSRC2022_dev-dev_06521',
#  'VoxSRC2022_dev-dev_01306',
#  'VoxSRC2022_dev-dev_01673',
#  'VoxSRC2022_dev-dev_06552',
#  'VoxSRC2022_dev-dev_01315',
#  'VoxSRC2022_dev-dev_00352',
#  'VoxSRC2022_dev-dev_02387',
#  'VoxSRC2022_dev-dev_00595',
#  'VoxSRC2022_dev-dev_03015',
#  'VoxSRC2022_dev-dev_05910',
#  'VoxSRC2022_dev-dev_00518',
#  'VoxSRC2022_dev-dev_05051',
#  'VoxSRC2022_dev-dev_00809',
#  'VoxSRC2022_dev-dev_02916',
#  'VoxSRC2022_dev-dev_05150',
#  'VoxSRC2022_dev-dev_06655',
#  'VoxSRC2022_dev-dev_04988',
#  'VoxSRC2022_dev-dev_02062',
#  'VoxSRC2022_dev-dev_02248',
#  'VoxSRC2022_dev-dev_00403',
#  'VoxSRC2022_dev-dev_00028',
#  'VoxSRC2022_dev-dev_03312',
#  'VoxSRC2022_dev-dev_00829',
#  'VoxSRC2022_dev-dev_05993',
#  'VoxSRC2022_dev-dev_01113',
#  'VoxSRC2022_dev-dev_03453',
#  'VoxSRC2022_dev-dev_06209',
#  'VoxSRC2022_dev-dev_01020',
#  'VoxSRC2022_dev-dev_01400',
#  'VoxSRC2022_dev-dev_03942',
#  'VoxSRC2022_dev-dev_05967',
#  'VoxSRC2022_dev-dev_00160',
#  'VoxSRC2022_dev-dev_04698',
#  'VoxSRC2022_dev-dev_06402',
#  'VoxSRC2022_dev-dev_03331',
#  'VoxSRC2022_dev-dev_05551',
#  'VoxSRC2022_dev-dev_04824',
#  'VoxSRC2022_dev-dev_05524',
#  'VoxSRC2022_dev-dev_00786',
#  'VoxSRC2022_dev-dev_02154',
#  'VoxSRC2022_dev-dev_03382',
#  'VoxSRC2022_dev-dev_04217',
#  'VoxSRC2022_dev-dev_06077',
#  'VoxSRC2022_dev-dev_00201',
#  'VoxSRC2022_dev-dev_05066',
#  'VoxSRC2022_dev-dev_02866',
#  'VoxSRC2022_dev-dev_00813',
#  'VoxSRC2022_dev-dev_05872',
#  'VoxSRC2022_dev-dev_04561',
#  'VoxSRC2022_dev-dev_02600',
#  'VoxSRC2022_dev-dev_03367',
#  'VoxSRC2022_dev-dev_03509',
#  'VoxSRC2022_dev-dev_05602',
#  'VoxSRC2022_dev-dev_06656',
#  'VoxSRC2022_dev-dev_01242',
#  'VoxSRC2022_dev-dev_02839',
#  'VoxSRC2022_dev-dev_04695',
#  'VoxSRC2022_dev-dev_03720',
#  'VoxSRC2022_dev-dev_00333',
#  'VoxSRC2022_dev-dev_03861',
#  'VoxSRC2022_dev-dev_02250',
#  'VoxSRC2022_dev-dev_05112',
#  'VoxSRC2022_dev-dev_05693',
#  'VoxSRC2022_dev-dev_03003',
#  'VoxSRC2022_dev-dev_00339',
#  'VoxSRC2022_dev-dev_01988',
#  'VoxSRC2022_dev-dev_02362',
#  'VoxSRC2022_dev-dev_05211',
#  'VoxSRC2022_dev-dev_03051',
#  'VoxSRC2022_dev-dev_01032',
#  'VoxSRC2022_dev-dev_05756',
#  'VoxSRC2022_dev-dev_06053',
#  'VoxSRC2022_dev-dev_00211',
#  'VoxSRC2022_dev-dev_06576',
#  'VoxSRC2022_dev-dev_05971',
#  'VoxSRC2022_dev-dev_00394',
#  'VoxSRC2022_dev-dev_00880',
#  'VoxSRC2022_dev-dev_04273',
#  'VoxSRC2022_dev-dev_06560',
#  'VoxSRC2022_dev-dev_06165',
#  'VoxSRC2022_dev-dev_00274',
#  'VoxSRC2022_dev-dev_01884',
#  'VoxSRC2022_dev-dev_00924',
#  'VoxSRC2022_dev-dev_02236',
#  'VoxSRC2022_dev-dev_02912',
#  'VoxSRC2022_dev-dev_02560',
#  'VoxSRC2022_dev-dev_05852',
#  'VoxSRC2022_dev-dev_00912',
#  'VoxSRC2022_dev-dev_05073',
#  'VoxSRC2022_dev-dev_04512',
#  'VoxSRC2022_dev-dev_02342',
#  'VoxSRC2022_dev-dev_02392',
#  'VoxSRC2022_dev-dev_01715',
#  'VoxSRC2022_dev-dev_02365',
#  'VoxSRC2022_dev-dev_01090',
#  'VoxSRC2022_dev-dev_02223',
#  'VoxSRC2022_dev-dev_01269',
#  'VoxSRC2022_dev-dev_03662',
#  'VoxSRC2022_dev-dev_05414',
#  'VoxSRC2022_dev-dev_01399',
#  'VoxSRC2022_dev-dev_04581',
#  'VoxSRC2022_dev-dev_04660',
#  'VoxSRC2022_dev-dev_03104',
#  'VoxSRC2022_dev-dev_05512',
#  'VoxSRC2022_dev-dev_06639',
#  'VoxSRC2022_dev-dev_01660',
#  'VoxSRC2022_dev-dev_03952',
#  'VoxSRC2022_dev-dev_04767',
#  'VoxSRC2022_dev-dev_02461',
#  'VoxSRC2022_dev-dev_02005',
#  'VoxSRC2022_dev-dev_05906',
#  'VoxSRC2022_dev-dev_05069',
#  'VoxSRC2022_dev-dev_03167',
#  'VoxSRC2022_dev-dev_03150',
#  'VoxSRC2022_dev-dev_04959',
#  'VoxSRC2022_dev-dev_00752',
#  'VoxSRC2022_dev-dev_00111',
#  'VoxSRC2022_dev-dev_00878',
#  'VoxSRC2022_dev-dev_04140',
#  'VoxSRC2022_dev-dev_06225',
#  'VoxSRC2022_dev-dev_01402',
#  'VoxSRC2022_dev-dev_04868',
#  'VoxSRC2022_dev-dev_04533',
#  'VoxSRC2022_dev-dev_00441',
#  'VoxSRC2022_dev-dev_03471',
#  'VoxSRC2022_dev-dev_01503',
#  'VoxSRC2022_dev-dev_05218',
#  'VoxSRC2022_dev-dev_05021',
#  'VoxSRC2022_dev-dev_05867',
#  'VoxSRC2022_dev-dev_02039',
#  'VoxSRC2022_dev-dev_00219',
#  'VoxSRC2022_dev-dev_01946',
#  'VoxSRC2022_dev-dev_01228',
#  'VoxSRC2022_dev-dev_04338',
#  'VoxSRC2022_dev-dev_05492',
#  'VoxSRC2022_dev-dev_00173',
#  'VoxSRC2022_dev-dev_02078',
#  'VoxSRC2022_dev-dev_01362',
#  'VoxSRC2022_dev-dev_01642',
#  'VoxSRC2022_dev-dev_04326',
#  'VoxSRC2022_dev-dev_02809',
#  'VoxSRC2022_dev-dev_01767',
#  'VoxSRC2022_dev-dev_06256',
#  'VoxSRC2022_dev-dev_05598',
#  'VoxSRC2022_dev-dev_05234',
#  'VoxSRC2022_dev-dev_00427',
#  'VoxSRC2022_dev-dev_05996',
#  'VoxSRC2022_dev-dev_02948',
#  'VoxSRC2022_dev-dev_01364',
#  'VoxSRC2022_dev-dev_01766',
#  'VoxSRC2022_dev-dev_04056',
#  'VoxSRC2022_dev-dev_03265',
#  'VoxSRC2022_dev-dev_01671',
#  'VoxSRC2022_dev-dev_04242',
#  'VoxSRC2022_dev-dev_03415',
#  'VoxSRC2022_dev-dev_00776',
#  'VoxSRC2022_dev-dev_04601',
#  'VoxSRC2022_dev-dev_03087',
#  'VoxSRC2022_dev-dev_02069',
#  'VoxSRC2022_dev-dev_01754',
#  'VoxSRC2022_dev-dev_02815',
#  'VoxSRC2022_dev-dev_02271',
#  'VoxSRC2022_dev-dev_00133',
#  'VoxSRC2022_dev-dev_02880',
#  'VoxSRC2022_dev-dev_00804',
#  'VoxSRC2022_dev-dev_00016',
#  'VoxSRC2022_dev-dev_02974',
#  'VoxSRC2022_dev-dev_05816',
#  'VoxSRC2022_dev-dev_06213',
#  'VoxSRC2022_dev-dev_00719',
#  'VoxSRC2022_dev-dev_00386',
#  'VoxSRC2022_dev-dev_00202',
#  'VoxSRC2022_dev-dev_04144',
#  'VoxSRC2022_dev-dev_05080',
#  'VoxSRC2022_dev-dev_05326',
#  'VoxSRC2022_dev-dev_03650',
#  'VoxSRC2022_dev-dev_02272',
#  'VoxSRC2022_dev-dev_02512',
#  'VoxSRC2022_dev-dev_01607',
#  'VoxSRC2022_dev-dev_02473',
#  'VoxSRC2022_dev-dev_06111',
#  'VoxSRC2022_dev-dev_00996',
#  'VoxSRC2022_dev-dev_02458',
#  'VoxSRC2022_dev-dev_02311',
#  'VoxSRC2022_dev-dev_01860',
#  'VoxSRC2022_dev-dev_04093',
#  'VoxSRC2022_dev-dev_02902',
#  'VoxSRC2022_dev-dev_00193',
#  'VoxSRC2022_dev-dev_04610',
#  'VoxSRC2022_dev-dev_00735',
#  'VoxSRC2022_dev-dev_05239',
#  'VoxSRC2022_dev-dev_04870',
#  'VoxSRC2022_dev-dev_04361',
#  'VoxSRC2022_dev-dev_00161',
#  'VoxSRC2022_dev-dev_03788',
#  'VoxSRC2022_dev-dev_04543',
#  'VoxSRC2022_dev-dev_02610',
#  'VoxSRC2022_dev-dev_02643',
#  'VoxSRC2022_dev-dev_03026',
#  'VoxSRC2022_dev-dev_02011',
#  'VoxSRC2022_dev-dev_02357',
#  'VoxSRC2022_dev-dev_05464',
#  'VoxSRC2022_dev-dev_05397',
#  'VoxSRC2022_dev-dev_01699',
#  'VoxSRC2022_dev-dev_01486',
#  'VoxSRC2022_dev-dev_00807',
#  'VoxSRC2022_dev-dev_06354',
#  'VoxSRC2022_dev-dev_04967',
#  'VoxSRC2022_dev-dev_02595',
#  'VoxSRC2022_dev-dev_02952',
#  'VoxSRC2022_dev-dev_05197',
#  'VoxSRC2022_dev-dev_04530',
#  'VoxSRC2022_dev-dev_06680',
#  'VoxSRC2022_dev-dev_03113',
#  'VoxSRC2022_dev-dev_03282',
#  'VoxSRC2022_dev-dev_05214',
#  'VoxSRC2022_dev-dev_03645',
#  'VoxSRC2022_dev-dev_05377',
#  'VoxSRC2022_dev-dev_01062',
#  'VoxSRC2022_dev-dev_05842',
#  'VoxSRC2022_dev-dev_01550',
#  'VoxSRC2022_dev-dev_01120',
#  'VoxSRC2022_dev-dev_06045',
#  'VoxSRC2022_dev-dev_01035',
#  'VoxSRC2022_dev-dev_00380',
#  'VoxSRC2022_dev-dev_00014',
#  'VoxSRC2022_dev-dev_04191',
#  'VoxSRC2022_dev-dev_06127',
#  'VoxSRC2022_dev-dev_04667',
#  'VoxSRC2022_dev-dev_05678',
#  'VoxSRC2022_dev-dev_06310',
#  'VoxSRC2022_dev-dev_04979',
#  'VoxSRC2022_dev-dev_05421',
#  'VoxSRC2022_dev-dev_05733',
#  'VoxSRC2022_dev-dev_00582',
#  'VoxSRC2022_dev-dev_05246',
#  'VoxSRC2022_dev-dev_00295',
#  'VoxSRC2022_dev-dev_02066',
#  'VoxSRC2022_dev-dev_02287',
#  'VoxSRC2022_dev-dev_00304',
#  'VoxSRC2022_dev-dev_06391',
#  'VoxSRC2022_dev-dev_03911',
#  'VoxSRC2022_dev-dev_03124',
#  'VoxSRC2022_dev-dev_04628',
#  'VoxSRC2022_dev-dev_03937',
#  'VoxSRC2022_dev-dev_01169',
#  'VoxSRC2022_dev-dev_00743',
#  'VoxSRC2022_dev-dev_01200',
#  'VoxSRC2022_dev-dev_04018',
#  'VoxSRC2022_dev-dev_00205',
#  'VoxSRC2022_dev-dev_06171',
#  'VoxSRC2022_dev-dev_02084',
#  'VoxSRC2022_dev-dev_04104',
#  'VoxSRC2022_dev-dev_05785',
#  'VoxSRC2022_dev-dev_00115',
#  'VoxSRC2022_dev-dev_05978',
#  'VoxSRC2022_dev-dev_01729',
#  'VoxSRC2022_dev-dev_00904',
#  'VoxSRC2022_dev-dev_02421',
#  'VoxSRC2022_dev-dev_05471',
#  'VoxSRC2022_dev-dev_06365',
#  'VoxSRC2022_dev-dev_00385',
#  'VoxSRC2022_dev-dev_05709',
#  'VoxSRC2022_dev-dev_03185',
#  'VoxSRC2022_dev-dev_02378',
#  'VoxSRC2022_dev-dev_02972',
#  'VoxSRC2022_dev-dev_01505',
#  'VoxSRC2022_dev-dev_04672',
#  'VoxSRC2022_dev-dev_03805',
#  'VoxSRC2022_dev-dev_06510',
#  'VoxSRC2022_dev-dev_05608',
#  'VoxSRC2022_dev-dev_00535',
#  'VoxSRC2022_dev-dev_01749',
#  'VoxSRC2022_dev-dev_05031',
#  'VoxSRC2022_dev-dev_03448',
#  'VoxSRC2022_dev-dev_01980',
#  'VoxSRC2022_dev-dev_03731',
#  'VoxSRC2022_dev-dev_05639',
#  'VoxSRC2022_dev-dev_00218',
#  'VoxSRC2022_dev-dev_03354',
#  'VoxSRC2022_dev-dev_06254',
#  'VoxSRC2022_dev-dev_00087',
#  'VoxSRC2022_dev-dev_03623',
#  'VoxSRC2022_dev-dev_05455',
#  'VoxSRC2022_dev-dev_04716',
#  'VoxSRC2022_dev-dev_01772',
#  'VoxSRC2022_dev-dev_00570',
#  'VoxSRC2022_dev-dev_00915',
#  'VoxSRC2022_dev-dev_02941',
#  'VoxSRC2022_dev-dev_00278',
#  'VoxSRC2022_dev-dev_01036',
#  'VoxSRC2022_dev-dev_01638',
#  'VoxSRC2022_dev-dev_05833',
#  'VoxSRC2022_dev-dev_01419',
#  'VoxSRC2022_dev-dev_05036',
#  'VoxSRC2022_dev-dev_02309',
#  'VoxSRC2022_dev-dev_02455',
#  'VoxSRC2022_dev-dev_06620',
#  'VoxSRC2022_dev-dev_05333',
#  'VoxSRC2022_dev-dev_06304',
#  'VoxSRC2022_dev-dev_00460',
#  'VoxSRC2022_dev-dev_05002',
#  'VoxSRC2022_dev-dev_05306',
#  'VoxSRC2022_dev-dev_04783',
#  'VoxSRC2022_dev-dev_02542',
#  'VoxSRC2022_dev-dev_03458',
#  'VoxSRC2022_dev-dev_02317',
#  'VoxSRC2022_dev-dev_00623',
#  'VoxSRC2022_dev-dev_00577',
#  'VoxSRC2022_dev-dev_06175',
#  'VoxSRC2022_dev-dev_03653',
#  'VoxSRC2022_dev-dev_04011',
#  'VoxSRC2022_dev-dev_01344',
#  'VoxSRC2022_dev-dev_04287',
#  'VoxSRC2022_dev-dev_01853',
#  'VoxSRC2022_dev-dev_03587',
#  'VoxSRC2022_dev-dev_05163',
#  'VoxSRC2022_dev-dev_04626',
#  'VoxSRC2022_dev-dev_05270',
#  'VoxSRC2022_dev-dev_02592',
#  'VoxSRC2022_dev-dev_02644',
#  'VoxSRC2022_dev-dev_00366',
#  'VoxSRC2022_dev-dev_00702',
#  'VoxSRC2022_dev-dev_01201',
#  'VoxSRC2022_dev-dev_00854',
#  'VoxSRC2022_dev-dev_05742',
#  'VoxSRC2022_dev-dev_01347',
#  'VoxSRC2022_dev-dev_00650',
#  'VoxSRC2022_dev-dev_02799',
#  'VoxSRC2022_dev-dev_02793',
#  'VoxSRC2022_dev-dev_02733',
#  'VoxSRC2022_dev-dev_03712',
#  'VoxSRC2022_dev-dev_04117',
#  'VoxSRC2022_dev-dev_04902',
#  'VoxSRC2022_dev-dev_02046',
#  'VoxSRC2022_dev-dev_06470',
#  'VoxSRC2022_dev-dev_00326',
#  'VoxSRC2022_dev-dev_02221',
#  'VoxSRC2022_dev-dev_01051',
#  'VoxSRC2022_dev-dev_03253',
#  'VoxSRC2022_dev-dev_02551',
#  'VoxSRC2022_dev-dev_06327',
#  'VoxSRC2022_dev-dev_03164',
#  'VoxSRC2022_dev-dev_01595',
#  'VoxSRC2022_dev-dev_02515',
#  'VoxSRC2022_dev-dev_00638',
#  'VoxSRC2022_dev-dev_01556',
#  'VoxSRC2022_dev-dev_03892',
#  'VoxSRC2022_dev-dev_00988',
#  'VoxSRC2022_dev-dev_06634',
#  'VoxSRC2022_dev-dev_02474',
#  'VoxSRC2022_dev-dev_03970',
#  'VoxSRC2022_dev-dev_04199',
#  'VoxSRC2022_dev-dev_01676',
#  'VoxSRC2022_dev-dev_01731',
#  'VoxSRC2022_dev-dev_06601',
#  'VoxSRC2022_dev-dev_06149',
#  'VoxSRC2022_dev-dev_01125',
#  'VoxSRC2022_dev-dev_02450',
#  'VoxSRC2022_dev-dev_05814',
#  'VoxSRC2022_dev-dev_00099',
#  'VoxSRC2022_dev-dev_02478',
#  'VoxSRC2022_dev-dev_03280',
#  'VoxSRC2022_dev-dev_04007',
#  'VoxSRC2022_dev-dev_05452',
#  'VoxSRC2022_dev-dev_00787',
#  'VoxSRC2022_dev-dev_01155',
#  'VoxSRC2022_dev-dev_04229',
#  'VoxSRC2022_dev-dev_04154',
#  'VoxSRC2022_dev-dev_02812',
#  'VoxSRC2022_dev-dev_00803',
#  'VoxSRC2022_dev-dev_01947',
#  'VoxSRC2022_dev-dev_06466',
#  'VoxSRC2022_dev-dev_04502',
#  'VoxSRC2022_dev-dev_04681',
#  'VoxSRC2022_dev-dev_05381',
#  'VoxSRC2022_dev-dev_04455',
#  'VoxSRC2022_dev-dev_04491',
#  'VoxSRC2022_dev-dev_04715',
#  'VoxSRC2022_dev-dev_04026',
#  'VoxSRC2022_dev-dev_02302',
#  'VoxSRC2022_dev-dev_02875',
#  'VoxSRC2022_dev-dev_02829',
#  'VoxSRC2022_dev-dev_02037',
#  'VoxSRC2022_dev-dev_03839',
#  'VoxSRC2022_dev-dev_06181',
#  'VoxSRC2022_dev-dev_02363',
#  'VoxSRC2022_dev-dev_03068',
#  'VoxSRC2022_dev-dev_03320',
#  'VoxSRC2022_dev-dev_03546',
#  'VoxSRC2022_dev-dev_01294',
#  'VoxSRC2022_dev-dev_05242',
#  'VoxSRC2022_dev-dev_04418',
#  'VoxSRC2022_dev-dev_02020',
#  'VoxSRC2022_dev-dev_00841',
#  'VoxSRC2022_dev-dev_03459',
#  'VoxSRC2022_dev-dev_05057',
#  'VoxSRC2022_dev-dev_05562',
#  'VoxSRC2022_dev-dev_02789',
#  'VoxSRC2022_dev-dev_02807',
#  'VoxSRC2022_dev-dev_04264',
#  'VoxSRC2022_dev-dev_00792',
#  'VoxSRC2022_dev-dev_05479',
#  'VoxSRC2022_dev-dev_05791',
#  'VoxSRC2022_dev-dev_01207',
#  'VoxSRC2022_dev-dev_03849',
#  'VoxSRC2022_dev-dev_05453',
#  'VoxSRC2022_dev-dev_03973',
#  'VoxSRC2022_dev-dev_02966',
#  'VoxSRC2022_dev-dev_05376',
#  'VoxSRC2022_dev-dev_00575',
#  'VoxSRC2022_dev-dev_02545',
#  'VoxSRC2022_dev-dev_04164',
#  'VoxSRC2022_dev-dev_05478',
#  'VoxSRC2022_dev-dev_01274',
#  'VoxSRC2022_dev-dev_03112',
#  'VoxSRC2022_dev-dev_02841',
#  'VoxSRC2022_dev-dev_05761',
#  'VoxSRC2022_dev-dev_01480',
#  'VoxSRC2022_dev-dev_01687',
#  'VoxSRC2022_dev-dev_06125',
#  'VoxSRC2022_dev-dev_04534',
#  'VoxSRC2022_dev-dev_05713',
#  'VoxSRC2022_dev-dev_02345',
#  'VoxSRC2022_dev-dev_06630',
#  'VoxSRC2022_dev-dev_00736',
#  'VoxSRC2022_dev-dev_06583',
#  'VoxSRC2022_dev-dev_05884',
#  'VoxSRC2022_dev-dev_02759',
#  'VoxSRC2022_dev-dev_05092',
#  'VoxSRC2022_dev-dev_02203',
#  'VoxSRC2022_dev-dev_01614',
#  'VoxSRC2022_dev-dev_04879',
#  'VoxSRC2022_dev-dev_05325',
#  'VoxSRC2022_dev-dev_05957',
#  'VoxSRC2022_dev-dev_03753',
#  'VoxSRC2022_dev-dev_04761',
#  'VoxSRC2022_dev-dev_04051',
#  'VoxSRC2022_dev-dev_06130',
#  'VoxSRC2022_dev-dev_00953',
#  'VoxSRC2022_dev-dev_06124',
#  'VoxSRC2022_dev-dev_06574',
#  'VoxSRC2022_dev-dev_01115',
#  'VoxSRC2022_dev-dev_04790',
#  'VoxSRC2022_dev-dev_03818',
#  'VoxSRC2022_dev-dev_02796',
#  'VoxSRC2022_dev-dev_03129',
#  'VoxSRC2022_dev-dev_02313',
#  'VoxSRC2022_dev-dev_04643',
#  'VoxSRC2022_dev-dev_04874',
#  'VoxSRC2022_dev-dev_03654',
#  'VoxSRC2022_dev-dev_00764',
#  'VoxSRC2022_dev-dev_02371',
#  'VoxSRC2022_dev-dev_06081',
#  'VoxSRC2022_dev-dev_05521',
#  'VoxSRC2022_dev-dev_05789',
#  'VoxSRC2022_dev-dev_01123',
#  'VoxSRC2022_dev-dev_01405',
#  'VoxSRC2022_dev-dev_06191',
#  'VoxSRC2022_dev-dev_05620',
#  'VoxSRC2022_dev-dev_00490',
#  'VoxSRC2022_dev-dev_01148',
#  'VoxSRC2022_dev-dev_03684',
#  'VoxSRC2022_dev-dev_03606',
#  'VoxSRC2022_dev-dev_04780',
#  'VoxSRC2022_dev-dev_03897',
#  'VoxSRC2022_dev-dev_04447',
#  'VoxSRC2022_dev-dev_03867',
#  'VoxSRC2022_dev-dev_03694',
#  'VoxSRC2022_dev-dev_05918',
#  'VoxSRC2022_dev-dev_00318',
#  'VoxSRC2022_dev-dev_04216',
#  'VoxSRC2022_dev-dev_06011',
#  'VoxSRC2022_dev-dev_02230',
#  'VoxSRC2022_dev-dev_01111',
#  'VoxSRC2022_dev-dev_00516',
#  'VoxSRC2022_dev-dev_01131',
#  'VoxSRC2022_dev-dev_01255',
#  'VoxSRC2022_dev-dev_00463',
#  'VoxSRC2022_dev-dev_03243',
#  'VoxSRC2022_dev-dev_00558',
#  'VoxSRC2022_dev-dev_00942',
#  'VoxSRC2022_dev-dev_04789',
#  'VoxSRC2022_dev-dev_02831',
#  'VoxSRC2022_dev-dev_03971',
#  'VoxSRC2022_dev-dev_04293',
#  'VoxSRC2022_dev-dev_03860',
#  'VoxSRC2022_dev-dev_03071',
#  'VoxSRC2022_dev-dev_00044',
#  'VoxSRC2022_dev-dev_04135',
#  'VoxSRC2022_dev-dev_01163',
#  'VoxSRC2022_dev-dev_00397',
#  'VoxSRC2022_dev-dev_04240',
#  'VoxSRC2022_dev-dev_03131',
#  'VoxSRC2022_dev-dev_01648',
#  'VoxSRC2022_dev-dev_04573',
#  'VoxSRC2022_dev-dev_04568',
#  'VoxSRC2022_dev-dev_01920',
#  'VoxSRC2022_dev-dev_00875',
#  'VoxSRC2022_dev-dev_01528',
#  'VoxSRC2022_dev-dev_05243',
#  'VoxSRC2022_dev-dev_02499',
#  'VoxSRC2022_dev-dev_04220',
#  'VoxSRC2022_dev-dev_01068',
#  'VoxSRC2022_dev-dev_05177',
#  'VoxSRC2022_dev-dev_04682',
#  'VoxSRC2022_dev-dev_06499',
#  'VoxSRC2022_dev-dev_03750',
#  'VoxSRC2022_dev-dev_03782',
#  'VoxSRC2022_dev-dev_02666',
#  'VoxSRC2022_dev-dev_00616',
#  'VoxSRC2022_dev-dev_01412',
#  'VoxSRC2022_dev-dev_04262',
#  'VoxSRC2022_dev-dev_02353',
#  'VoxSRC2022_dev-dev_00550',
#  'VoxSRC2022_dev-dev_03199',
#  'VoxSRC2022_dev-dev_05807',
#  'VoxSRC2022_dev-dev_02486',
#  'VoxSRC2022_dev-dev_01848',
#  'VoxSRC2022_dev-dev_05543',
#  'VoxSRC2022_dev-dev_03676',
#  'VoxSRC2022_dev-dev_02324',
#  'VoxSRC2022_dev-dev_01259',
#  'VoxSRC2022_dev-dev_00379',
#  'VoxSRC2022_dev-dev_02824',
#  'VoxSRC2022_dev-dev_05463',
#  'VoxSRC2022_dev-dev_03370',
#  'VoxSRC2022_dev-dev_02846',
#  'VoxSRC2022_dev-dev_01349',
#  'VoxSRC2022_dev-dev_05747',
#  'VoxSRC2022_dev-dev_02251',
#  'VoxSRC2022_dev-dev_03096',
#  'VoxSRC2022_dev-dev_01266',
#  'VoxSRC2022_dev-dev_02278',
#  'VoxSRC2022_dev-dev_03230',
#  'VoxSRC2022_dev-dev_06239',
#  'VoxSRC2022_dev-dev_03542',
#  'VoxSRC2022_dev-dev_01392',
#  'VoxSRC2022_dev-dev_04283',
#  'VoxSRC2022_dev-dev_05033',
#  'VoxSRC2022_dev-dev_03198',
#  'VoxSRC2022_dev-dev_02153',
#  'VoxSRC2022_dev-dev_04678',
#  'VoxSRC2022_dev-dev_00098',
#  'VoxSRC2022_dev-dev_00697',
#  'VoxSRC2022_dev-dev_06097',
#  'VoxSRC2022_dev-dev_01253',
#  'VoxSRC2022_dev-dev_04005',
#  'VoxSRC2022_dev-dev_05578',
#  'VoxSRC2022_dev-dev_06653',
#  'VoxSRC2022_dev-dev_05945',
#  'VoxSRC2022_dev-dev_00539',
#  'VoxSRC2022_dev-dev_04501',
#  'VoxSRC2022_dev-dev_03200',
#  'VoxSRC2022_dev-dev_03991',
#  'VoxSRC2022_dev-dev_06072',
#  'VoxSRC2022_dev-dev_05350',
#  'VoxSRC2022_dev-dev_04435',
#  'VoxSRC2022_dev-dev_06582',
#  'VoxSRC2022_dev-dev_05223',
#  'VoxSRC2022_dev-dev_02399',
#  'VoxSRC2022_dev-dev_05577',
#  'VoxSRC2022_dev-dev_05893',
#  ...]
