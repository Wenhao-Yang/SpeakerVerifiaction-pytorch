# %%
import librosa
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
melfb = librosa.filters.mel(16000, 400, 12, norm=None)
plt.figure(figsize=(12,3))
for i,x in enumerate(melfb):
#     if i<6:
    plt.plot(x)

plt.show()
