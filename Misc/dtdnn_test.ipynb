# %%
import torch
from Define_Model.TDNN.DTDNN import DTDNN

# %%
model = DTDNN(num_classes=1211)
x = torch.rand(128, 30, 300)

# %%
y = model(x)
# model

# %%
y.shape
# Out:
# torch.Size([128, 1211])
