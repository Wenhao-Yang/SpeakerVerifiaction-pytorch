# %%
from Misc.HST.short_SHT import short_SHT
import matplotlib.pyplot as plt
import soundfile as sf

# %%
data, fs = sf.read('/home/yangwenhao/storage/dataset/voxceleb1/voxceleb1_wav/vox1_dev_wav/wav/id10001/1zcIwhmdeo4/00001.wav')


# plt.figure(figsize=(12, 5))

insf_all, inse_all, s_list, t = short_SHT(data[:16000], fs, win=2000, a = 0.05, s = 20, isPlot = False)

# %%
print(insf_all.shape)
print(inse_all.shape)
# Out:
# (20, 16000)
# (20, 16000)

# %%
s_list
# Out:
# [11, 10, 13, 10, 12, 11, 12, 11, 12, 13, 14, 12, 12, 12, 13, 13]

# %%
plt.figure(figsize=(21, 5))
plt.imshow(insf_all[:,:1000])
