# %%
import torch

# Model
model = torch.hub.load("ultralytics/yolov5", "yolov5s")  # or yolov5n - yolov5x6, custom
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /home/yangwenhao/.cache/torch/hub/master.zip
# requirements: YOLOv5 requirements "gitpython>=3.1.30" "tqdm>=4.64.0" "setuptools>=65.5.1" not found, attempting AutoUpdate...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 1.2.3 requires tensorboard>=2.2.0, which is not installed.
# ...
#   Using cached GitPython-3.1.31-py3-none-any.whl (184 kB)
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.63.1
#     Uninstalling tqdm-4.63.1:
#       Successfully uninstalled tqdm-4.63.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 52.0.0.post20210125
#     Uninstalling setuptools-52.0.0.post20210125:
#       Successfully uninstalled setuptools-52.0.0.post20210125
#   Attempting uninstall: gitpython
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Images
# img = "./d181b2c4ly1g28djk87tnj20c80gb0u4.jpg"  # or file, Path, PIL, OpenCV, numpy, list
img = './d181b2c4ly1g28djk7n5zj20c8095abg.jpg'
# Inference
results = model(img)

# Results
results.save('result2.png')  # or .show(), .save(), .crop(), .pandas(), etc.
# Out:
# Saved 1 image to runs/detect/exp2

# %%
print(results.xywh)
# Out:
# [tensor([[ 29.50226,  85.26746,  28.71950,  92.67722,   0.81520,   0.00000],
#         [119.27303,  87.36435,  25.27418,  82.42365,   0.32296,   0.00000],
# ...

# %%
# import cv2
# img_cv = cv2.imread(img)
# img_plt = plt.imread(img)
# plt.imshow(img_plt, cmap=plt.cm.binary)

import matplotlib.image as mpig
img_mpig = mpig.imread(img)#读取数据
plt.imshow(img_mpig)

# for i in (results.xyxy)[0]:
#     i = i.cpu().numpy()
#     print(i)
#     plt.plot([i[0], i[0], i[2], i[2], i[0]],  [i[1], i[3],  i[3], i[1], i[1]])

plt.axis('off')
# Out:
# (-0.5, 131.5, 131.5, -0.5)

# %%
# plt.imshow(img)
plt.imshow(results.ims[0])

# %%
results.xyxy
# Out:
# [tensor([[ 15.14251,  38.92885,  43.86201, 131.60606,   0.81520,   0.00000],
#          [106.63593,  46.15252, 131.91011, 128.57617,   0.32296,   0.00000],
#          [ 48.12850,  44.21620,  71.65745,  92.14725,   0.25933,   0.00000]], device='cuda:0')]
